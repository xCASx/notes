# %% [markdown]
# # Top univercities courses:
#
# 1. MIT 6.S094: Deep Learning for Self-Driving Cars:
# https://www.youtube.com/watch?v=1L0TKZQcUtA&list=PLrAXtmErZgOeiKm4sgNOknGvNjby9efdf
# 2. MIT 6.034 Artificial Intelligence, Fall 2010:
# https://www.youtube.com/watch?v=TjZBTDzGeGg&list=PLUl4u3cNGP63gFHB6xb-kVBiQHYe_4hSi
# 3. Caltech Machine Learning Course - CS 156:
# https://www.youtube.com/watch?v=mbyG85GZ0PI&list=PLD63A284B7615313A
# 4. Stanford cs231n Winter 2016 Convolutional Neural Networks for Visual Recognition:
# https://www.youtube.com/watch?v=g-PvXUjD6qg&list=PLlJy-eBtNFt6EuMxFYRiNRS07MCWN5UIA
# Notes: http://cs231n.github.io/
# 5. Oxford Deep Learning for NLP at Oxford with Deep Mind 2017:
# https://www.youtube.com/watch?v=RP3tZFcC2e8&list=PL613dYIGMXoZBtZhbyiBqb0QtgK6oJbpm
# Code: https://github.com/oxford-cs-deepnlp-2017
# 6. Awesome courses. Machine Learning.
# https://github.com/prakhar1989/awesome-courses/#machine-learning
# 7. Yandex Academy. Machine Learning cource 2014:
# https://www.youtube.com/playlist?list=PLJOzdkh8T5kp99tGTEFjH_b9zqEQiiBtC
# 8. Deep Learning Summer School, Montreal 2016: http://videolectures.net/deeplearning2016_montreal/
# 9. Berkeley Artificial Intelligence CS 188 Spring 2016:
# https://www.youtube.com/watch?v=3aCn2-Slaoc&list=PLIeooNSdhQE5kRrB71yu5yP9BRCJCSbMt
# 10. Stanford Deep Learning Tutorial: http://ufldl.stanford.edu/tutorial/
# 11. Stanford CS224d: Deep Learning for NLP 2016:
# https://www.youtube.com/watch?v=kZteabVD8sU&list=PLCJlDcMjVoEdtem5GaohTC1o9HTTFtK7 course http://cs224d.stanford.edu/
# 12. Andrew Ng's Deep learning course on Coursera: https://www.deeplearning.ai/

# %% [markdown]
# # Other useful courses:
#
# 1. Udacity Intro to Parallel Programming: https://www.udacity.com/course/intro-to-parallel-programming--cs344
# 2. TensorFlow: https://www.youtube.com/watch?v=wuo4JdG3SvU&list=PL9Hr9sNUjfsmEu1ZniY0XpHSzl5uihcXZ
# 3. TensorFlow for Poets: https://codelabs.developers.google.com/codelabs/tensorflow-for-poets/#0
# 4. Every single Machine Learning course on the internet, ranked by your reviews: https://medium.freecodecamp.org/every-single-machine-learning-course-on-the-internet-ranked-by-your-reviews-3c4a7b8026c0
# 5. Data Science 101 (Getting started in NLP): Tokenization tutorial http://blog.kaggle.com/2017/08/25/data-science-101-getting-started-in-nlp-tokenization-tutorial/
#
# ## Math
# 1. Khan Academy Math course: https://www.khanacademy.org/math
# 2. Khan Academy Linear algebra: https://www.khanacademy.org/math/linear-algebra
# 3. Essence of linear algebra: https://www.youtube.com/playlist?list=PLZHQObOWTQDPD3MizzM2xVFitgF8hE_ab
# 4. Essence of calculus: https://www.youtube.com/playlist?list=PLZHQObOWTQDMsr9K-rj53DwVRMYO3t5Yr
# 5. Computational Linear Algebra for Coders: https://github.com/fastai/numerical-linear-algebra/blob/master/README.md

# %% [markdown]
# # Other videos:
#
# 1. Who is Afraid of Non-Convex Loss Functions? http://videolectures.net/eml07_lecun_wia/
# 2. Tensorflow and deep learning - without a PhD by Martin Görner: https://www.youtube.com/watch?v=vq2nnJ4g6N0
# 3. TensorFlow Tutorial #02 Convolutional Neural Network: https://www.youtube.com/watch?v=HMcx-zY8JSg
# 4. Visualizing and Understanding Deep Neural Networks by Matt Zeiler: https://www.youtube.com/watch?v=ghEmQSxT6tw
# 5. Live Q&A with the Deep Learning Foundations Team: https://www.youtube.com/watch?v=HgLplBRpRcs

# %% [markdown]
# # Books:
#
# 1. Deep Learning. Ian Goodfellow and Yoshua Bengio and Aaron Courville. MIT Press.
# http://www.deeplearningbook.org/
# 2. Neural Networks and Deep Learning. Michael Nielsen.
# http://neuralnetworksanddeeplearning.com/
# 3. Free Machine Learning eBooks:
# https://www.packtpub.com/books/content/free-machine-learning-ebooks/
# 4. Grokking Deep Learning. Andrew W. Trask.
# https://www.goodreads.com/book/show/31565758-grokking-deep-learning
# 5. Artificial Inteligence:
# https://leonardoaraujosantos.gitbooks.io/artificial-inteligence/content/chapter1.html
# 6. Bootstrapping Machine Learning. Louis Dorard.
# http://www.louisdorard.com/machine-learning-book/
# 7. The Quest for Artificial Intelligence. Nils J. Nilsson. Cambridge University Press.
# https://www.amazon.com/Quest-Artificial-Intelligence-Nils-Nilsson/dp/0521122937/?tag=widgetsamazon-20
# Free PDF: http://ai.stanford.edu/~nilsson/QAI/qai.pdf
# 8. Artificial Intelligence: Foundations of Computational Agents. David L. Poole. Cambridge University Press.
# https://www.amazon.com/Artificial-Intelligence-Foundations-Computational-Agents/dp/0521519004/?tag=widgetsamazon-20
# 9. Reinforcement Learning: An Introduction (Adaptive Computation and Machine Learning). Richard S. Sutton.
# https://www.amazon.com/Reinforcement-Learning-Introduction-Adaptive-Computation/dp/0262193981/?tag=widgetsamazon-20
# 10. Machine Learning: An Algorithmic Perspective (Chapman & Hall/Crc Machine Learning & Pattern Recognition). Stephen Marsland. https://www.amazon.com/Machine-Learning-Algorithmic-Perspective-Recognition/dp/1420067184
# 11. Machine Learning: A Probabilistic Perspective. Kevin P. Murphy. MIT Press.
# https://www.goodreads.com/book/show/15857489-machine-learning
# 12. Gödel, Escher, Bach: An Eternal Golden Braid. Douglas R. Hofstadter.
# https://www.amazon.com/G%C3%B6del-Escher-Bach-Eternal-Golden/dp/0465026567 MIT course: https://ocw.mit.edu/high-school/humanities-and-social-sciences/godel-escher-bach/ course content: https://www.youtube.com/watch?v=5jFhq3Rj6DI
# 13. Applied Predictive Modeling. Max Kuhn, Kjell Johnson https://www.amazon.com/dp/1461468485

# %% [markdown]
# # Audiobooks:
# 1. Machines of Loving Grace: The Quest for Common Ground Between Humans and Robots. John Markoff.
# https://www.amazon.com/Machines-Loving-Grace-Common-Between/dp/B00Y3VXZSG
# 2. The Singularity Is Near: When Humans Transcend Biology. Ray Kurzweil.
# https://www.amazon.com/Singularity-Near-Humans-Transcend-Biology/dp/B004ZF18PW
# 3. How to Create a Mind: The Secret of Human Thought Revealed. Ray Kurzweil.
# https://www.amazon.com/How-Create-Mind-Thought-Revealed-ebook/dp/B007V65UUG
# 4. Philosophy of Mind: Brains, Consciousness, and Thinking Machines. The Great Courses, Professor Patrick Grim.
# https://www.amazon.com/Philosophy-Mind-Consciousness-Thinking-Machines/dp/B00DTO5LQC
# 5. Superintelligence: Paths, Dangers, Strategies. Nick Bostrom.
# https://www.amazon.com/dp/B00LPMFE9Y/
# 6. The Master Algorithm: How the Quest for the Ultimate Learning Machine Will Remake Our World. Pedro Domingos.
# https://www.amazon.com/Master-Algorithm-Ultimate-Learning-Machine/dp/B014X01SS0

# %% [markdown]
# # Cool services / tools:
#
# 1. Google AI experiments: https://aiexperiments.withgoogle.com/
# 2. Linear Classification Loss Visualization: http://vision.stanford.edu/teaching/cs231n/linear-classify-demo/
# 3. Deep Learning for Java: https://deeplearning4j.org/index.html
# 4. Eliminate engineering bottlenecks in Deep Learning: https://www.floydhub.com/
# 5. Word2Vec by Google: https://code.google.com/archive/p/word2vec/
# 6. Udacity Self Driving Car Simulator: https://github.com/udacity/self-driving-car-sim
# 7. Scientific search https://www.wolframalpha.com/
# 8. Plot functions online: https://www.desmos.com/
# 9. Become a Data Scientist: https://www.dataquest.io/
# 10. A growing collection of evolution simulation games: https://evolsim.itch.io/
# 11. Yolo - realtime object detection: https://pjreddie.com/darknet/yolo/
# 12. 3D Convolutional Network visualization: http://scs.ryerson.ca/~aharley/vis/conv/
# 13. Maze Hover (Labirint): https://bl.ocks.org/mbostock/6ba3a15c9f08742b3a80
# 14. OpenAI Gym: https://gym.openai.com/
# 15. Weka 3: Data Mining Software in Java: http://www.cs.waikato.ac.nz/ml/weka/
# 16. deeplearn.js a hardware-accelerated machine intelligence library for the web: https://pair-code.github.io/deeplearnjs/
# 17. Netscope. A web-based tool for visualizing neural network architectures (or technically, any directed acyclic graph): https://ethereon.github.io/netscope/quickstart.html
# 18. STMVis - Visual Analysis for Recurrent Neural Networks http://lstm.seas.harvard.edu/
# 19. Beautiful thematic maps with ggplot2 (only) https://timogrossenbacher.ch/2016/12/beautiful-thematic-maps-with-ggplot2-only/
# 20. Deep Visualization Toolbox https://github.com/yosinski/deep-visualization-toolbox
# 21. Neural network visualization toolkit for keras https://github.com/raghakot/keras-vis
#
# ## Style transfer
# 1. http://www.pikazoapp.com/
# 2. https://deepart.io/
# 3. https://artisto.my.com/
# 4. https://prisma-ai.com/

# %% [markdown]
# # Competitions / Datasets:
# 1. The biggest community: https://www.kaggle.com/
# 2. Data science competitions to save the world: https://www.drivendata.org/
# 3. DeepTraffic. 6.S094: Deep Learning for Self-Driving Cars:
# http://selfdrivingcars.mit.edu/deeptraffic/
# 4. CIPHER WAR. After a century of failing to crack an ancient script, linguists turn to machines:
# http://www.theverge.com/2017/1/25/14371450/indus-valley-civilization-ancient-seals-symbols-language-algorithms-ai
# 5. Google Cloud and YouTube-8M Challenge: Predict YouTube video tags for a chance to win up to $30K: https://cloud.google.com/blog/big-data/2017/02/google-cloud-and-youtube-8m-challenge-predict-youtube-video-tags-for-a-chance-to-win-up-to-30k
# 6. THE MNIST DATABASE of handwritten digits: http://yann.lecun.com/exdb/mnist/
# 7. Fueling the Gold Rush: The Greatest Public Datasets for AI
# https://medium.com/startup-grind/fueling-the-ai-gold-rush-7ae438505bc2#.lslws43jc
# 8. Boston Housing dataset: https://archive.ics.uci.edu/ml/datasets/Housing
# 9. Financial Datasets: https://www.quandl.com/ and https://www.quantopian.com/home
# 10. The CIFAR-10 dataset: https://www.cs.toronto.edu/~kriz/cifar.html
# 11. Machine learning repository: http://archive.ics.uci.edu/ml/datasets.html
# 12. notMNIST: http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html
# 13. Classification datasets results. Discover the current state of the art in objects classification:
# http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html
# 14. CS543/ECE549 Assignment 4: Deep Convolutional Neural Networks:
# https://inclass.kaggle.com/c/computer-vision-cs543-ece549

# %% [markdown]
# # Practical guides:
#
# 1. Deep Learning, Applied. Project #1. Food Classification with Deep Learning in Keras / Tensorflow:
# http://blog.stratospark.com/deep-learning-applied-food-classification-deep-learning-keras.html
# 2. AI Tool Building. Accelerating Deep Learning with Multiprocess Image Augmentation in Keras:
# http://blog.stratospark.com/multiprocess-image-augmentation-keras.html#multiprocess-image-augmentation-keras
# 3. Build custom TensorFlow: https://www.tensorflow.org/install/install_sources and https://github.com/tensorflow/tensorflow/blob/master/tensorflow/g3doc/get_started/os_setup.md
# 4. TensorFlow Examples: https://github.com/aymericdamien/TensorFlow-Examples
# 5. Practical tutorials, videos and challenges to learn new technologies, libraries and techniques: https://cambridgespark.com/content
# 6. Running the Udacity Deep Learning Foundations image classification project on floydhub.com:
# https://github.com/ludwiktrammer/deep-learning/tree/master/image-classification
# 7. 37 причин, почему ваша нейросеть не работает: https://habrahabr.ru/post/334944/
# 8. Building Trust in Machine Learning Models (using LIME in Python): https://www.analyticsvidhya.com/blog/2017/06/building-trust-in-machine-learning-models/
# 9. How to train a neural network to code by itself? https://becominghuman.ai/how-to-train-a-neural-network-to-code-by-itself-a432e8a120df
# 10. Building a Facial Recognition Pipeline with Deep Learning in Tensorflow https://hackernoon.com/building-a-facial-recognition-pipeline-with-deep-learning-in-tensorflow-66e7645015b8
# 11. Launch a GPU-backed Google Compute Engine instance and setup Tensorflow, Keras and Jupyter https://hackernoon.com/launch-a-gpu-backed-google-compute-engine-instance-and-setup-tensorflow-keras-and-jupyter-902369ed5272

# %% [markdown]
# # Whitepapers:
#
# 1. Awesome - Most Cited Deep Learning Papers: https://github.com/terryum/awesome-deep-learning-papers
# 2. MIT Evolving Neural Networks through Augmenting Topologies:
# http://nn.cs.utexas.edu/downloads/papers/stanley.ec02.pdf
# 3. Google's Rules of Machine Learning: Best Practices for ML Engineering (Martin Zinkevich):
# http://martin.zinkevich.org/rules_of_ml/rules_of_ml.pdf
# 4. Understanding Neural Networks Through Deep Visualization:
# http://yosinski.com/media/papers/Yosinski__2015__ICML_DL__Understanding_Neural_Networks_Through_Deep_Visualization__.pdf
# 5. LIPNET: END-TO-END SENTENCE-LEVEL LIPREADING: http://www.oxml.co.uk/publications/2016-Assael_Shillingford_LipNet.pdf Youtube video: LipNet in Autonomous Vehicles | CES 2017: https://www.youtube.com/watch?v=YTkqA189pzQ
# 6. DEEPCODER: LEARNING TO WRITE PROGRAMS: https://openreview.net/pdf?id=ByldLrqlx
# 7. Learning long-term dependencies with gradient descent is difficult: http://www.dsi.unifi.it/~paolo/ps/tnn-94-gradient.pdf
# 8. Dropout: A Simple Way to Prevent Neural Networks from Overfitting: https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf
# 9. List of recent whitepapers:
# https://docs.google.com/spreadsheets/d/1MT8LRuEn3xdJ7j6_XQjRZwV_fRmrpjaWwZKGk2Dqm4k/edit#gid=0
# 10. On the Origin of Deep Learning: https://arxiv.org/abs/1702.07800
# 11. Visual Question Answering Using Attention based Models: https://nishantrai18.github.io/resources/cs676_report.pdf
# 12. Deep Forest: Towards An Alternative to Deep Neural Networks: https://arxiv.org/abs/1702.08835
# 13. A\* Sampling: https://papers.nips.cc/paper/5449-a-sampling.pdf
# 14. All you need is a good init: https://arxiv.org/abs/1511.06422
# 15. Batch Normalization: Accelerating Deep Network Training by Reducing Internal Covariate Shift:
# https://arxiv.org/abs/1502.03167
# 16. Transfer Learning: ftp://ftp.cs.wisc.edu/machine-learning/shavlik-group/torrey.handbook09.pdf
# 17. Efficient Online and Batch Learning Using Forward Backward Splitting:
# http://machinelearning.wustl.edu/mlpapers/paper_files/jmlr10_duchi09a.pdf
# 18. Intriguing properties of neural networks: https://arxiv.org/abs/1312.6199 PDF: https://cs.nyu.edu/~zaremba/docs/understanding.pdf
# 19. Deal or No Deal? End-to-End Learning for Negotiation Dialogues: https://arxiv.org/abs/1706.05125
# 20. One Model To Learn Them All: https://arxiv.org/abs/1706.05137
# 21. Deep Bilateral Learning for Real-Time Image Enhancement http://groups.csail.mit.edu/graphics/hdrnet/data/hdrnet.pdf
# 22. Comparison of 13 classic ML algorithms on 165 datasets. Data-driven Advice for Applying Machine Learning to Bioinformatics Problems https://arxiv.org/abs/1708.05070

# %% [markdown]
# ## Convolutional
# 1. Visualizing and Understanding Convolutional Networks: http://www.matthewzeiler.com/pubs/arxive2013/eccv2014.pdf
# 2. ImageNet Classification with Deep Convolutional Neural Networks: http://www.cs.toronto.edu/~fritz/absps/imagenet.pdf
# 3. Delving Deep into Rectifiers: Surpassing Human-Level Performance on ImageNet Classification: https://arxiv.org/pdf/1502.01852.pdf
# 4. Optimization on Submanifolds of Convolution Kernels in CNNs: https://arxiv.org/abs/1610.07008#
# 5. A Neural Algorithm of Artistic Style: https://arxiv.org/abs/1508.06576
# 6. A Fully Convolutional Neural Network for Speech Enhancement: https://arxiv.org/abs/1609.07132
# 7. Learning to Segment Object Candidates: https://arxiv.org/abs/1506.06204
# 8. The 9 Deep Learning Papers You Need To Know About (Understanding CNNs Part 3):
# https://adeshpande3.github.io/adeshpande3.github.io/The-9-Deep-Learning-Papers-You-Need-To-Know-About.html
# 9. You Only Look Once: Unified, Real-Time Object Detection: https://pjreddie.com/media/files/papers/yolo_1.pdf
# 10. PixelNN: Example-based Image Synthesis http://www.cs.cmu.edu/~aayushb/pixelNN/
# 11. BlitzNet: A Real-Time Deep Network for Scene Understanding http://thoth.inrialpes.fr/research/blitznet/
#
# ## RNN
# 1. Chinese Poetry Generation with Recurrent Neural Networks: http://www.aclweb.org/anthology/D14-1074
# 2. Automated Crowdturfing Attacks and Defenses in Online Review Systems: https://arxiv.org/abs/1708.08151
#
# ## Reinforncement Learning
# 1. Reinforcement learning in the brain: http://www.princeton.edu/~yael/Publications/Niv2009.pdf
#
# ## SVM
# 1. Text Categorization with Support Vector Machines: Learning with Many Relevant Features:
# http://www.cs.cornell.edu/people/tj/publications/joachims_98a.pdf
#
# ## Sentiment Analysis
# 1. A comparison of Lexicon-based approaches for Sentiment Analysis of microblog posts:
# http://ceur-ws.org/Vol-1314/paper-06.pdf
#
# ## Multimodal
# 1. Multimodal Deep Learning: https://people.csail.mit.edu/khosla/papers/icml2011_ngiam.pdf

# %% [markdown]
# # Math:
# 1. Linear algebra explained in four pages: http://www.souravsengupta.com/cds2016/lectures/Savov_Notes.pdf
# 2. Calculus Cheat Sheet: http://tutorial.math.lamar.edu/pdf/Calculus_Cheat_Sheet_All.pdf
# 3. Statistics cheatsheet: http://web.mit.edu/~csvoss/Public/usabo/stats_handout.pdf
# 4. Math for Machine Learning: https://people.ucsc.edu/~praman1/static/pub/math-for-ml.pdf
# 5. The Mathematics of Deep Learning:
# http://www.vision.jhu.edu/tutorials/ICCV15-Tutorial-Math-Deep-Learning-Intro-Rene-Joan.pdf
# 6. The Mathematics of Machine Learning: http://datascience.ibm.com/blog/the-mathematics-of-machine-learning/
# 7. Linear Algebra: http://www.deeplearningbook.org/contents/linear_algebra.html

# %% [markdown]
# # Various materials:
#
# 1. The 10 Algorithms Machine Learning Engineers Need to Know: http://www.kdnuggets.com/2016/08/10-algorithms-machine-learning-engineers.html
# 2. 10 Popular Java Machine Learning Tools & Libraries:
# http://www.datasciencecentral.com/profiles/blogs/10-popular-java-machine-learning-tools-libraries
# 3. Deep Learning for Noobs: https://hackernoon.com/supervised-deep-learning-in-image-classification-for-noobs-part-1-9f831b6d430d#.liec70fzq
# 4. Bag of Words Meets Bags of Popcorn: https://www.kaggle.com/c/word2vec-nlp-tutorial
# 5. Softmax Regression:
# http://ufldl.stanford.edu/tutorial/supervised/SoftmaxRegression/
# 6. Understanding the Bias-Variance Tradeoff: http://scott.fortmann-roe.com/docs/BiasVariance.html
# 7. A Tour of Machine Learning Algorithms: http://machinelearningmastery.com/a-tour-of-machine-learning-algorithms/
# 8. TensorFlow in a Nutshell — Part One: Basics: http://camron.xyz/index.php/2016/08/22/in_a_nutshell_part_one/
# 9. Advanced Natural Language Processing Tools for Bot Makers – LUIS, Wit.ai, Api.ai and others: https://stanfy.com/blog/advanced-natural-language-processing-tools-for-bot-makers/
# 10. The Black Magic of Deep Learning - Tips and Tricks for the practitioner:
# https://nmarkou.blogspot.com.cy/2017/02/the-black-magic-of-deep-learning-tips.html
# 11. Image-to-Image Translation in Tensorflow: http://affinelayer.com/pix2pix/index.html
# 12. Image-to-Image Demo. Interactive Image Translation with pix2pix-tensorflow: https://affinelayer.com/pixsrv/
# 13. Yes you should understand backprop: https://medium.com/@karpathy/yes-you-should-understand-backprop-e2f06eab496b#.gwed5ainp
# 14. Blog notes of ML newbe: Getting Started with Machine Learning:
# http://www.theamazingfedex.com/2017/02/getting-started-with-machine-learning.html
# 15. Attacking machine learning with adversarial examples: https://openai.com/blog/adversarial-example-research/
# 16. ELI5 for deep learning. Simple explanations for complex concepts. ELI5 means Explain like I'm 5 years old. https://deep-learning-concepts.appspot.com/
# 17. Preprocessing for Machine Learning with tf.Transform:
# https://research.googleblog.com/2017/02/preprocessing-for-machine-learning-with.html?m=1
# 18. Neural Network Hyperparameters: http://colinraffel.com/wiki/neural_network_hyperparameters
# 19. Deep Forest: Towards an Alternative to Deep Neural Networks: https://news.ycombinator.com/item?id=13773127
# 20. Choosing the right estimator: http://scikit-learn.org/stable/tutorial/machine_learning_map/
# 21. Deep Visual-Semantic Alignments for Generating Image Descriptions: http://cs.stanford.edu/people/karpathy/deepimagesent/
# 22. TensorFlow Wide & Deep Learning Tutorial: https://www.tensorflow.org/tutorials/wide_and_deep
# 23. Ensemble Learning. Better Predictions Through Diversity: http://abeautifulwww.com/EnsembleLearningETech.pdf
# 24. ReLU Was Yesterday, Tomorrow Comes ELU: http://www.picalike.com/blog/2015/11/28/relu-was-yesterday-tomorrow-comes-elu/
# 25. ResNets, HighwayNets, and DenseNets, Oh My!
# https://chatbotslife.com/resnets-highwaynets-and-densenets-oh-my-9bb15918ee32#.4lldkm8r8
# 26. Logarithmic Loss: https://www.kaggle.com/wiki/LogarithmicLoss
# 27. Hacker's guide to Neural Networks: http://karpathy.github.io/neuralnets/
# 28. Infographic: Best Practices for Training Deep Learning Networks:
# https://medium.com/intuitionmachine/infographic-best-practices-in-training-deep-learning-networks-b8a3df1db53#.jsfnrszdv
# 29. Understanding Neural Network Batch Training: A Tutorial:
# https://visualstudiomagazine.com/articles/2014/08/01/batch-training.aspx
# 30. Back propagation with TensorFlow: http://blog.aloni.org/posts/backprop-with-tensorflow/
# 31. Basic Concepts in Machine Learning: http://machinelearningmastery.com/basic-concepts-in-machine-learning/
# 32. The Unreasonable Effectiveness of Recurrent Neural Networks:
# http://karpathy.github.io/2015/05/21/rnn-effectiveness/
# 33. Sense2vec with spaCy and Gensim: https://explosion.ai/blog/sense2vec-with-spacy
# 34. Binary Classification Tutorial with the Keras Deep Learning Library: http://machinelearningmastery.com/binary-classification-tutorial-with-the-keras-deep-learning-library/
# 35. The Neural Network Zoo: http://www.asimovinstitute.org/neural-network-zoo/
# 36. How HBO’s Silicon Valley built “Not Hotdog” with mobile TensorFlow, Keras & React Native: https://hackernoon.com/how-hbos-silicon-valley-built-not-hotdog-with-mobile-tensorflow-keras-react-native-ef03260747f3
# 37. AI Designers Find Inspiration in Rat Brains: http://spectrum.ieee.org/biomedical/imaging/ai-designers-find-inspiration-in-rat-brains
# 38. The Dark Secret at the Heart of AI: https://www.technologyreview.com/s/604087/the-dark-secret-at-the-heart-of-ai/
# 39. Достижения в глубоком обучении за последний год: https://habrahabr.ru/company/mailru/blog/338248/
# 40. Google shows how easy it is for software to remove watermarks from photos https://www.theverge.com/2017/8/18/16162108/google-research-algorithm-watermark-removal-photo-protection
# 41. Netflix's architecture. Distributed Time Travel for Feature Generation https://medium.com/netflix-techblog/distributed-time-travel-for-feature-generation-389cccdd3907
# 42. A mindmap summarising Machine Learning concepts, from Data Analysis to Deep Learning. Machine Learning Mindmap / Cheatsheet https://github.com/dformoso/machine-learning-mindmap
# 43. https://github.com/MrMimic/data-scientist-roadmap Toturial coming with "data science roadmap" graphe. http://nirvacana.com/thoughts/becoming-a-data-scientist/

# %% [markdown]
# ## Q&A:
# 1. What is batch size in neural network?
# http://stats.stackexchange.com/questions/153531/what-is-batch-size-in-neural-network
# 2. multi-layer perceptron (MLP) architecture: criteria for choosing number of hidden layers and size of the hidden layer?
# http://stackoverflow.com/questions/10565868/multi-layer-perceptron-mlp-architecture-criteria-for-choosing-number-of-hidde
# 3. How does transfer learning work? https://www.quora.com/How-does-transfer-learning-work
# 4. How do I decide the number of nodes in a hidden layer of a neural network?
# https://www.quora.com/How-do-I-decide-the-number-of-nodes-in-a-hidden-layer-of-a-neural-network
# 5. How does ELU activation function help convergence, and what's its advantages over ReLU or sigmoid or tanh function?
# https://www.quora.com/How-does-ELU-activation-function-help-convergence-and-whats-its-advantages-over-ReLU-or-sigmoid-or-tanh-function
# 6. What's the difference between gradient descent and stochastic gradient descent?
# https://www.quora.com/Whats-the-difference-between-gradient-descent-and-stochastic-gradient-descent
# 7. Tradeoff batch size vs. number of iterations to train a neural network:
# http://stats.stackexchange.com/questions/164876/tradeoff-batch-size-vs-number-of-iterations-to-train-a-neural-network
# 8. Why should weights of Neural Networks be initialized to random numbers?
# http://stackoverflow.com/questions/20027598/why-should-weights-of-neural-networks-be-initialized-to-random-numbers
# 9. What are good initial weights in a neural network?
# https://www.quora.com/What-are-good-initial-weights-in-a-neural-network
# 10. How do you initialize your neural network weights?
# https://www.reddit.com/r/MachineLearning/comments/2qsje7/how_do_you_initialize_your_neural_network_weights/
# 11. Where do I call the BatchNormalization function in Keras?
# http://stackoverflow.com/questions/34716454/where-do-i-call-the-batchnormalization-function-in-keras

# %% [markdown]
# ## Convolutional
# 1. Convolutional Neural Networks (LeNet): http://deeplearning.net/tutorial/lenet.html
# 2. Convolutional Neural Network: http://ufldl.stanford.edu/tutorial/supervised/ConvolutionalNeuralNetwork/
# 3. A Beginner's Guide To Understanding Convolutional Neural Networks:
# https://adeshpande3.github.io/adeshpande3.github.io/A-Beginner's-Guide-To-Understanding-Convolutional-Neural-Networks/
# 4. An Intuitive Explanation of Convolutional Neural Networks:
# https://ujjwalkarn.me/2016/08/11/intuitive-explanation-convnets/
# 5. UNDERSTANDING CONVOLUTIONAL NEURAL NETWORKS FOR NLP:
# http://www.wildml.com/2015/11/understanding-convolutional-neural-networks-for-nlp/
# 6. http://neuralnetworksanddeeplearning.com/chap6.html
# 7. Convolutional Neural Networks (CNNs): An Illustrated Explanation:
# http://xrds.acm.org/blog/2016/06/convolutional-neural-networks-cnns-illustrated-explanation/
# 8. Convolutional Neural Networks (Andrew Gibiansky's blog):
# http://andrew.gibiansky.com/blog/machine-learning/convolutional-neural-networks/
# 9. Machine Learning is Fun! Part 3: Deep Learning and Convolutional Neural Networks:
# https://medium.com/@ageitgey/machine-learning-is-fun-part-3-deep-learning-and-convolutional-neural-networks-f40359318721#.h6uqq3etp
# 10. One by One [ 1 x 1 ] Convolution - counter-intuitively useful:
# http://iamaaditya.github.io/2016/03/one-by-one-convolution/
# 11. Using convolutional neural nets to detect facial keypoints tutorial:
# http://danielnouri.org/notes/2014/12/17/using-convolutional-neural-nets-to-detect-facial-keypoints-tutorial/
# 12. Picasso: A free open-source visualizer for Convolutional Neural Networks: https://medium.com/merantix/picasso-a-free-open-source-visualizer-for-cnns-d8ed3a35cfc5
# 13. Convolutional Methods for Text: https://medium.com/@TalPerry/convolutional-methods-for-text-d5260fd5675f
#
# ### Style transfer
# 1. Convolutional neural networks for artistic style transfer:
# https://harishnarayanan.org/writing/artistic-style-transfer/
# 2. Style transfer: https://ml4a.github.io/ml4a/style_transfer/
# 3. Experiments with style transfer: http://genekogan.com/works/style-transfer/
# 4. How do these "neural network style transfer" tools work? https://jvns.ca/blog/2017/02/12/neural-style/

# %% [markdown]
# ## Recommender Systems
# 1. Evaluating Recommender Systems - Explaining F-Score, Recall and Precision using Real Data Set from Apontador:
# http://aimotion.blogspot.com/2011/05/evaluating-recommender-systems.html
# 2. Applying Deep Learning to Collaborative Filtering: How Hulu builds its industry leading recommendation engine:
# http://tech.hulu.com/blog/2016/08/01/cfnade.html
# 3. Co-occurrence Approach to an Item Based Recommender:
# https://blogs.msdn.microsoft.com/carlnol/2012/06/23/co-occurrence-approach-to-an-item-based-recommender/
# 4. An Inside Look at the Components of a Recommendation Engine:
# https://www.mapr.com/blog/inside-look-at-components-of-recommendation-engine
# 5. Item-to-Item Collaborative Filtering and Matrix Factorization:
# https://www.ics.uci.edu/~welling/teaching/CS77Bwinter12/presentations/course_Ricci/13-Item-to-Item-Matrix-CF.pdf
# 6. Quick Guide to Build a Recommendation Engine in Python:
# https://www.analyticsvidhya.com/blog/2016/06/quick-guide-build-recommendation-engine-python/
# 7. How to Build a Recommender System: http://blogs.gartner.com/martin-kihn/how-to-build-a-recommender-system-in-python/

# %% [markdown]
# ## Sentiment Analysis
# 1. Deep Learning Sentiment One Character at a T-i-m-e:
# https://gab41.lab41.org/deep-learning-sentiment-one-character-at-a-t-i-m-e-6cd96e4f780d#.1d6tewmhs
# 2. How is deep learning used in sentiment analysis?
# https://www.quora.com/How-is-deep-learning-used-in-sentiment-analysis
# 3. Lexicon-Based Methods for Sentiment Analysis: https://www.aclweb.org/anthology/J/J11/J11-2001.pdf

# %% [markdown]
# ## RNN
# 1. Introduction to Recurrent Networks and Applications in EEG Analysis: http://www.cs.colostate.edu/~idfah/main/tutorials/eegrnn
# 2. Recurrent Neural Networks in Tensorflow I: http://r2rt.com/recurrent-neural-networks-in-tensorflow-i.html
# 3. Recurrent Neural Networks: https://www.tensorflow.org/tutorials/recurrent
# 4. Lab 12-1 RNN Basics:
# https://docs.google.com/presentation/d/1UpZVnOvouIbXd0MAFBltSra5rRpsiJ-UyBUKGCrfYoo/edit#slide=id.g1ed9069b96_0_184
# 5. Going Deeper Into Reinforcement Learning: Understanding Q-Learning and Linear Function Approximation: https://danieltakeshi.github.io/2016/10/31/going-deeper-into-reinforcement-learning-understanding-q-learning-and-linear-function-approximation/
# 6. Deep Learning for NLP Best Practices: http://ruder.io/deep-learning-nlp-best-practices/

# %% [markdown]
# ## LSTM
# 1. Written Memories: Understanding, Deriving and Extending the LSTM:
# http://r2rt.com/written-memories-understanding-deriving-and-extending-the-lstm.html
# 2. Understanding LSTM Networks: http://colah.github.io/posts/2015-08-Understanding-LSTMs/
# 3. LSTM Networks for Sentiment Analysis on Tweets:
# http://k8si.github.io/2016/01/28/lstm-networks-for-sentiment-analysis-on-tweets.html
# 4. A noob’s guide to implementing RNN-LSTM using Tensorflow:
# http://monik.in/a-noobs-guide-to-implementing-rnn-lstm-using-tensorflow/
# 5. LSTM Networks for Sentiment Analysis: http://deeplearning.net/tutorial/lstm.html
# 6. A Beginner’s Guide to Recurrent Networks and LSTMs: https://deeplearning4j.org/lstm.html
# 7. Time Series Prediction with LSTM Recurrent Neural Networks in Python with Keras:
# http://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/
# 8. Demystifying LSTM neural networks:
# https://blog.terminal.com/demistifying-long-short-term-memory-lstm-recurrent-neural-networks/
# 9. Exploring LSTMs: http://blog.echen.me/2017/05/30/exploring-lstms/

# %% [markdown]
# ## GAN
# 1. Deep adversarial learning is finally ready 🚀 and will radically change the game: https://medium.com/intuitionmachine/deep-adversarial-learning-is-finally-ready-and-will-radically-change-the-game-f0cfda7b91d3
# 2. Work in progress: Portraits of Imaginary People: http://mtyka.github.io/machine/learning/2017/06/06/highres-gan-faces.html

# %% [markdown]
# # Blogs
# 1. Colah's blog: http://colah.github.io/
# 2. Hulu Tech Blog: http://tech.hulu.com/
# 3. Blog of Andrej Karpaty: http://karpathy.github.io/
# 4. Fast AI blog: http://www.fast.ai/
# 5. Darknet - Joseph Chet Redmon's blog: https://pjreddie.com/
# 6. Xu Cui: http://www.alivelearn.net/
# 7. Apple Machine Learning Journal: https://machinelearning.apple.com/

# %% [markdown]
# # Communities:
# 1. Reddit channel Machine Learning: https://www.reddit.com/r/MachineLearning/
# 2. Reddit channel Deep Learning: https://www.reddit.com/r/deeplearning/
# 3. Udacity deep learning nano degree Slack channel: https://nd101.slack.com/
# 4. Siraj's Slack channel: https://programming-wizards.slack.com/

# %% [markdown]
# # Youtube channels:
# 1. sentdex: https://www.youtube.com/channel/UCfzlCWGWYyIQ0aLC5w48gBQ
# 2. Welch Labs: https://www.youtube.com/channel/UConVfxXodg78Tzh5nNu85Ew
# 3. Zafarullah Mahmood: https://www.youtube.com/channel/UCG0Qzlcp-p9bKIojn3OCzdA
# 4. Jeremy Howard: https://www.youtube.com/channel/UCX7Y2qWriXpqocG97SFW2OQ
# 5. Thales Sehn Körting: https://www.youtube.com/channel/UCSd_7rz5nzSnzUYbjaCXC5g
# 6. Victor Lavrenko: https://www.youtube.com/channel/UCs7alOMRnxhzfKAJ4JjZ7Wg
# 7. Siraj Raval: https://www.youtube.com/channel/UCWN3xxRkmTPmbKwht9FuE5A
# 8. Computer Science Center: https://www.youtube.com/channel/UC0YHNueF-3Nh3uQT0P4YQZw
# 9. Neural Networks - The Nature of Code: https://www.youtube.com/playlist?list=PLRqwX-V7Uu6aCibgK1PTWWu9by6XFdCfh addition to The Nature of Code book: http://natureofcode.com/book/

# %% [markdown]
# # Podcasts:
#
# 1. Linear Digressions: http://lineardigressions.com/
# 2. Data Skeptic: https://dataskeptic.com/
# 3. Learning Machines 101: http://www.learningmachines101.com/
# 4. Machine Learning Guide: http://ocdevel.com/podcasts/machine-learning
# 5. The O'Reilly Data Show Podcast: https://www.oreilly.com/topics/oreilly-data-show-podcast
# 6. Talking Machines: http://www.thetalkingmachines.com/
# 7. Becoming a Data Scientist Podcast: http://www.becomingadatascientist.com/category/podcast/
# 8. Partially Derivative: http://partiallyderivative.com/

# %% [markdown]
# # Tools and Documentation:
#
# 1. Pandas: http://pandas.pydata.org/pandas-docs/stable/index.html
# 2. Scikit Learn (Python): http://scikit-learn.org/stable/user_guide.html
# 3. TFLearn: http://tflearn.org/
# 4. Keras: https://keras.io/
# 5. TensorFlow: https://www.tensorflow.org/api_docs/

# %% [markdown]
# # Hardware
# 1. Build a super fast deep learning machine for under \$1,000:
# https://www.oreilly.com/learning/build-a-super-fast-deep-learning-machine-for-under-1000
# 2. Build a Deep Learning Rig for $800:
# https://medium.com/@ncondo/build-a-deep-learning-rig-for-800-4434e21a424f#.77h84ur5f
# 3. Which GPU(s) to Get for Deep Learning: My Experience and Advice for Using GPUs in Deep Learning: http://timdettmers.com/2017/04/09/which-gpu-for-deep-learning/

# %% [markdown]
# # nd101 additional materials:
#
# 1. Preparation for Udacity Foundations of Deep Learning Nanodegree:
# https://docs.google.com/spreadsheets/d/1NZtIxDWiJ_B0UKhIDUk-wTZAT3Fxfh-fGwcQKXg1bQU/edit#gid=0
# 2. DL-ND LinkedIn Networking Sheet: https://docs.google.com/spreadsheets/d/1PWj19V9kb7A1V_Kagu29MWG41kvlXgNVLoSg7HN4P4s/edit#gid=0
# 3. Deep Learning Changelog 2/10:
# https://docs.google.com/document/d/1xIpSbMTYpf5g6fQ6vmGDFa21iDibQwWQ_oxITyfs1rE/edit#

# %% [markdown]
# # Slack nicknames:
# 1. Mat Leonard: @mat
# 2. Dhruv Parthasarathy (director of learning at Udacity): @dhruvp
# 3. Siraj Raval: @siraj
# 4. Andrew Trask: @trask
